# %%
from autogen_agentchat.agents import AssistantAgent,UserProxyAgent
from autogen_ext.models.openai import OpenAIChatCompletionClient
from autogen_agentchat.ui import Console
from autogen_agentchat.messages import TextMessage
from autogen_agentchat.conditions import TextMentionTermination
from autogen_core import CancellationToken

from dotenv import load_dotenv
import os
import asyncio

api_key=os.getenv('OPENAI_API_KEY')

model_client=OpenAIChatCompletionClient(model='gpt-4.1-mini',api_key=api_key)

assit_agent=AssistantAgent(name="assit_agent",
                       model_client=model_client,
                       system_message="You are a helpful assistant")
# Out:
# ---------------------------------------------------------------------------
# OpenAIError                               Traceback (most recent call last)
# Cell In[2], line 14
#      10 import asyncio
#      12 api_key=os.getenv('OPENAI_API_KEY')
# ---> 14 model_client=OpenAIChatCompletionClient(model='gpt-4.1-mini', api_key=api_key)
#      16 assit_agent=AssistantAgent(name="assit_agent",
#      17                        model_client=model_client,
#      18                        system_message="You are a helpful assistant")
#
# File c:\zPersonal\02 Selvarani R\GenAI\.venv\Lib\site-packages\autogen_ext\models\openai\_openai_client.py:1484, in OpenAIChatCompletionClient.__init__(self, **kwargs)
#    1481     if "api_key" not in copied_args and "LLAMA_API_KEY" in os.environ:
#    1482         copied_args["api_key"] = os.environ["LLAMA_API_KEY"]
# -> 1484 client = _openai_client_from_config(copied_args)
#    1485 create_args = _create_args_from_config(copied_args)
#    1487 super().__init__(
#    1488     client=client,
#    1489     create_args=create_args,
#    (...)   1493     include_name_in_message=include_name_in_message,
#    1494 )
#
# File c:\zPersonal\02 Selvarani R\GenAI\.venv\Lib\site-packages\autogen_ext\models\openai\_openai_client.py:134, in _openai_client_from_config(config)
#     131 def _openai_client_from_config(config: Mapping[str, Any]) -> AsyncOpenAI:
#     132     # Shave down the config to just the OpenAI kwargs
#     133     openai_config = {k: v for k, v in config.items() if k in openai_init_kwargs}
# --> 134     return AsyncOpenAI(**openai_config)
#
# File c:\zPersonal\02 Selvarani R\GenAI\.venv\Lib\site-packages\openai\_client.py:488, in AsyncOpenAI.__init__(self, api_key, organization, project, webhook_secret, base_url, websocket_base_url, timeout, max_retries, default_headers, default_query, http_client, _strict_response_validation)
#     486     api_key = os.environ.get("OPENAI_API_KEY")
#     487 if api_key is None:
# --> 488     raise OpenAIError(
#     489         "The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable"
#     490     )
#     491 if callable(api_key):
#     492     self.api_key = ""
#
# OpenAIError: The api_key client option must be set either by passing api_key to the client or by setting the OPENAI_API_KEY environment variable

# %%
user_agent=UserProxyAgent(name="user_agent",
                          description="It represents the user",
                          input_func=input)
